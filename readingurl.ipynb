# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://image.shutterstock.com/image-photo/rohu-fish-isolated-on-white-260nw-1477552211.jpg'
image=io.imread(url)
plt.imshow(image)
plt.show()

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img1=cv2.imread('img1.jpg')
img2=cv2.imread('img2.jpg')
fimg1=flower1+flowerpot1
plt.imshow(fimg1)
plt.show()
cv2.imwrite('output.jpg',fimg1)
fimg2=flower1-flowerpot1
plt.imshow(fimg2)
plt.show()
cv2.imwrite('output.jpg',fimg2)
fimg3=flower1*flowerpot1
plt.imshow(fimg3)
plt.show()
cv2.imwrite('output.jpg',fimg3)
fimg4=flower1/flowerpot1
plt.imshow(fimg4)
plt.show()
cv2.imwrite('output.jpg',fimg4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CENTRA~1\AppData\Local\Temp/ipykernel_1560/1531023924.py in <module>
#       4 img1=cv2.imread('flower1.jpg')
#       5 img2=cv2.imread('flowerpot1.jpg')
# ----> 6 fimg1=flower1+flowerpot1
#       7 plt.imshow(fimg1)
#       8 plt.show()
#
# NameError: name 'flower1' is not defined

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread('fish.jpg')
plt.imshow(img)
plt.show()

# %%
hsv_img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
light_orange=(1,190,200)
dark_orange=(18,255,255)
mask=cv2.inRange(hsv_img,light_orange,dark_orange)
result=cv2.bitwise_and(img,img,mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask,cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result)
plt.show()

# %%
light_white=(0,0,200)
dark_white=(145,60,255)
mask-white(cv2.inRange(hsv_img,light_white,dark_white))
